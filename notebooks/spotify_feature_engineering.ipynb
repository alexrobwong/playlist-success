# %%
import pandas as pd
import matplotlib.pyplot as plt
import logging
from tqdm import tqdm
import sys
import seaborn as sns
from copy import deepcopy
from scipy import stats
from functools import reduce

sns.set_style('darkgrid')
sys.path.append('/Users/alexander_wong/Documents/playlist-success/')

from src.data_transformations import create_features, classify_success, add_suffixes

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Merging playlist and track feature data
# This notebook combines each song in all avliable playlists with the downloaded song features

# %%
# Loading dataframes of spotify features per track_id
features_part_1 = pd.read_parquet('../data/track_features/track_features_all_half_1.parquet')
features_part_2 = pd.read_parquet('../data/track_features/track_features_all_half_2.parquet')
features_frame = pd.concat([features_part_1, features_part_2])

# %%
# Loading dataframe of all playlist_id and feature_ids
playlist_frame = all_tracks_frame = pd.read_parquet("../data/playlist_track_ids/playlist_track_ids_all.parquet")

# %%
playlist_frame
# Out:
#                   track_id  popularity                           user_id  \
# 0   5MiZ199HjYwrZfuNWVSxC9        30.0  6b7fbed9edd6418ddd3b555bba441536
# 1   3mqGTIR5BxJ678KkHFT4tg         2.0  6b7fbed9edd6418ddd3b555bba441536
# 2   2pOya9IyPgv2XLR7FfnySh         7.0  6b7fbed9edd6418ddd3b555bba441536
# 3   6SbP5526KNn4z2Dex2uf2B         0.0  6b7fbed9edd6418ddd3b555bba441536
# 4   6GjLKnNDVFsg6oLuplDwKF         0.0  6b7fbed9edd6418ddd3b555bba441536
# ..                     ...         ...                               ...
# 32  1qavn2qJRP3IoWnLkFzwI8         4.0  055d33003af0de47c79559c56ba6ee5b
# 0   6cLgBwRc1LfV0cSoboEfJD         0.0  4672952d42bdd93b9215ce9a40394ea6
# 1   4f0ldNhe5ZsIhzene1nup1        32.0  4672952d42bdd93b9215ce9a40394ea6
# 2   0DNk7lEqDGCN6nDD0H8emF         0.0  4672952d42bdd93b9215ce9a40394ea6
# 3   3Qi2o8uPKDByu6vFF1iq9d         0.0  4672952d42bdd93b9215ce9a40394ea6
#
#                playlist_id
# 0   6zpLN2wRu8z7fo4q6ouaAh
# 1   6zpLN2wRu8z7fo4q6ouaAh
# 2   6zpLN2wRu8z7fo4q6ouaAh
# 3   6zpLN2wRu8z7fo4q6ouaAh
# 4   6zpLN2wRu8z7fo4q6ouaAh
# ..                     ...
# 32  6orq0HsuzPGA1yOCNvCLMw
# 0   6W45lqDBZ1TKma71Uu2F5x
# 1   6W45lqDBZ1TKma71Uu2F5x
# 2   6W45lqDBZ1TKma71Uu2F5x
# 3   6W45lqDBZ1TKma71Uu2F5x
#
# [16456661 rows x 4 columns]

# %%
features_frame.head(10)
# Out:
#                  track_id  acousticness  danceability  duration  energy  \
# 0  5MiZ199HjYwrZfuNWVSxC9         0.488         0.812  191867.0   0.700
# 1  3mqGTIR5BxJ678KkHFT4tg         0.345         0.468  167208.0   0.715
# 2  2pOya9IyPgv2XLR7FfnySh         0.540         0.636  201853.0   0.783
# 3  6SbP5526KNn4z2Dex2uf2B         0.272         0.645  181360.0   0.465
# 4  6GjLKnNDVFsg6oLuplDwKF         0.821         0.562  175013.0   0.432
# 5  38TwIEwC3K5vgkPTrrUvzd         0.285         0.544  223920.0   0.491
# 6  2Av3o4sAszUWUS6WAEsXij         0.288         0.857  132107.0   0.912
# 7  2xjxGXr3eASzCvo9MUHk0w         0.702         0.646  204200.0   0.477
# 8  386yPOHFbMSXiniJ7UOai4         0.730         0.707  148907.0   0.693
# 9  58rgceeiYu1wFneDP2j5LJ         0.524         0.740  144147.0   0.849
#
#    instrumentalness   key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000001   7.0    0.3630    -3.579   1.0       0.0497  105.023
# 1          0.000000   7.0    0.1370    -5.671   1.0       0.1510  162.317
# 2          0.000000  11.0    0.3010    -3.918   1.0       0.0461  159.097
# 3          0.000000  11.0    0.1660    -6.630   1.0       0.0396  184.906
# 4          0.000006  10.0    0.0935    -4.441   1.0       0.0545  170.406
# 5          0.000003   0.0    0.2170    -4.288   1.0       0.0372  155.802
# 6          0.001540   0.0    0.5530    -4.310   1.0       0.0632  112.379
# 7          0.000000   7.0    0.0885    -5.610   0.0       0.0404  153.910
# 8          0.000016   5.0    0.0455    -5.438   1.0       0.0450  153.038
# 9          0.000000   3.0    0.0911    -3.171   1.0       0.1130  165.910
#
#    time  valence
# 0   4.0    0.925
# 1   4.0    0.803
# 2   3.0    0.892
# 3   3.0    0.952
# 4   3.0    0.950
# 5   3.0    0.516
# 6   3.0    0.985
# 7   3.0    0.941
# 8   3.0    0.988
# 9   3.0    0.964

# %%
# Check if there are any missing track features for each track id
missing_frame = playlist_frame.loc[lambda f: ~f['track_id'].isin(features_frame["track_id"])]

# %%
# %%time
combined_frame = pd.merge(playlist_frame, features_frame, how='left', on='track_id')
print("Merge Complete!")
# Out:
# Merge Complete!
# CPU times: user 13.2 s, sys: 2.62 s, total: 15.8 s
# Wall time: 16.6 s

# %%
# %%time
combined_frame.to_parquet("../data/playlist_track_features.parquet")
print("Save Complete!")
# Out:
# Save Complete!
# CPU times: user 13.7 s, sys: 6 s, total: 19.7 s
# Wall time: 16.6 s

# %%
combined_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16456661 entries, 0 to 16456660
# Data columns (total 17 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   track_id          object
#  1   popularity        float64
#  2   user_id           object
#  3   playlist_id       object
#  4   acousticness      float64
#  5   danceability      float64
#  6   duration          float64
#  7   energy            float64
#  8   instrumentalness  float64
#  9   key               float64
#  10  liveness          float64
#  11  loudness          float64
#  12  mode              float64
#  13  speechiness       float64
#  14  tempo             float64
#  15  time              float64
#  16  valence           float64
# dtypes: float64(14), object(3)
# memory usage: 2.2+ GB

# %%
combined_frame.describe()
# Out:
#          popularity  acousticness  danceability      duration        energy  \
# count  1.645666e+07  1.631872e+07  1.631872e+07  1.631872e+07  1.631872e+07
# mean   2.371073e+01  2.674312e-01  5.744729e-01  2.398144e+05  6.422404e-01
# std    2.529908e+01  3.119884e-01  1.744586e-01  1.042964e+05  2.371529e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+03  0.000000e+00
# 25%    0.000000e+00  1.460000e-02  4.630000e-01  1.933470e+05  4.900000e-01
# 50%    1.600000e+01  1.160000e-01  5.870000e-01  2.270000e+05  6.830000e-01
# 75%    4.500000e+01  4.630000e-01  7.010000e-01  2.688530e+05  8.330000e-01
# max    1.000000e+02  9.960000e-01  9.990000e-01  6.035552e+06  1.000000e+00
#
#        instrumentalness           key      liveness      loudness  \
# count      1.631872e+07  1.631872e+07  1.631872e+07  1.631872e+07
# mean       1.386322e-01  5.240539e+00  2.016597e-01 -8.060119e+00
# std        2.912138e-01  3.574927e+00  1.739368e-01  4.684500e+00
# min        0.000000e+00  0.000000e+00  0.000000e+00 -6.000000e+01
# 25%        0.000000e+00  2.000000e+00  9.500000e-02 -9.709000e+00
# 50%        4.100000e-05  5.000000e+00  1.290000e-01 -6.849000e+00
# 75%        2.890000e-02  8.000000e+00  2.600000e-01 -5.016000e+00
# max        1.000000e+00  1.100000e+01  1.000000e+00  4.923000e+00
#
#                mode   speechiness         tempo          time       valence
# count  1.631872e+07  1.631872e+07  1.631872e+07  1.631872e+07  1.631872e+07
# mean   6.554895e-01  9.400234e-02  1.213427e+02  3.911218e+00  4.916043e-01
# std    4.752084e-01  1.177563e-01  2.944623e+01  4.120838e-01  2.586609e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  3.570000e-02  9.812100e+01  4.000000e+00  2.830000e-01
# 50%    1.000000e+00  4.900000e-02  1.204630e+02  4.000000e+00  4.870000e-01
# 75%    1.000000e+00  9.430000e-02  1.399490e+02  4.000000e+00  6.990000e-01
# max    1.000000e+00  9.710000e-01  2.499870e+02  5.000000e+00  1.000000e+00

# %%
combined_frame
# Out:
#                         track_id  popularity  \
# 0         5MiZ199HjYwrZfuNWVSxC9        30.0
# 1         3mqGTIR5BxJ678KkHFT4tg         2.0
# 2         2pOya9IyPgv2XLR7FfnySh         7.0
# 3         6SbP5526KNn4z2Dex2uf2B         0.0
# 4         6GjLKnNDVFsg6oLuplDwKF         0.0
# ...                          ...         ...
# 16456656  1qavn2qJRP3IoWnLkFzwI8         4.0
# 16456657  6cLgBwRc1LfV0cSoboEfJD         0.0
# 16456658  4f0ldNhe5ZsIhzene1nup1        32.0
# 16456659  0DNk7lEqDGCN6nDD0H8emF         0.0
# 16456660  3Qi2o8uPKDByu6vFF1iq9d         0.0
#
#                                    user_id             playlist_id  \
# 0         6b7fbed9edd6418ddd3b555bba441536  6zpLN2wRu8z7fo4q6ouaAh
# 1         6b7fbed9edd6418ddd3b555bba441536  6zpLN2wRu8z7fo4q6ouaAh
# 2         6b7fbed9edd6418ddd3b555bba441536  6zpLN2wRu8z7fo4q6ouaAh
# 3         6b7fbed9edd6418ddd3b555bba441536  6zpLN2wRu8z7fo4q6ouaAh
# 4         6b7fbed9edd6418ddd3b555bba441536  6zpLN2wRu8z7fo4q6ouaAh
# ...                                    ...                     ...
# 16456656  055d33003af0de47c79559c56ba6ee5b  6orq0HsuzPGA1yOCNvCLMw
# 16456657  4672952d42bdd93b9215ce9a40394ea6  6W45lqDBZ1TKma71Uu2F5x
# 16456658  4672952d42bdd93b9215ce9a40394ea6  6W45lqDBZ1TKma71Uu2F5x
# 16456659  4672952d42bdd93b9215ce9a40394ea6  6W45lqDBZ1TKma71Uu2F5x
# 16456660  4672952d42bdd93b9215ce9a40394ea6  6W45lqDBZ1TKma71Uu2F5x
#
#           acousticness  danceability  duration  energy  instrumentalness  \
# 0               0.4880         0.812  191867.0   0.700          0.000001
# 1               0.3450         0.468  167208.0   0.715          0.000000
# 2               0.5400         0.636  201853.0   0.783          0.000000
# 3               0.2720         0.645  181360.0   0.465          0.000000
# 4               0.8210         0.562  175013.0   0.432          0.000006
# ...                ...           ...       ...     ...               ...
# 16456656        0.9930         0.432  113035.0   0.069          0.828000
# 16456657        0.0919         0.650  217278.0   0.762          0.001000
# 16456658        0.2130         0.436  221064.0   0.778          0.000050
# 16456659        0.0561         0.623  220291.0   0.656          0.000000
# 16456660        0.0964         0.766  224507.0   0.594          0.000219
#
#            key  liveness  loudness  mode  speechiness    tempo  time  valence
# 0          7.0    0.3630    -3.579   1.0       0.0497  105.023   4.0    0.925
# 1          7.0    0.1370    -5.671   1.0       0.1510  162.317   4.0    0.803
# 2         11.0    0.3010    -3.918   1.0       0.0461  159.097   3.0    0.892
# 3         11.0    0.1660    -6.630   1.0       0.0396  184.906   3.0    0.952
# 4         10.0    0.0935    -4.441   1.0       0.0545  170.406   3.0    0.950
# ...        ...       ...       ...   ...          ...      ...   ...      ...
# 16456656   7.0    0.1400   -19.528   0.0       0.0539  123.090   4.0    0.392
# 16456657   0.0    0.1070    -5.518   1.0       0.0401   93.032   4.0    0.452
# 16456658  10.0    0.1330    -5.139   0.0       0.1070  190.189   4.0    0.692
# 16456659   0.0    0.0855    -5.608   0.0       0.0416   95.878   4.0    0.366
# 16456660   5.0    0.1040    -9.636   0.0       0.0511  104.957   4.0    0.350
#
# [16456661 rows x 17 columns]

# %%
len(combined_frame["playlist_id"].unique())
# Out:
# 68352

# %%
(70399 - 68352)/70399 * 100
# Out:
# 2.9077117572692797

# %% [markdown]
# # Feature Engineering

# %%
combined_frame = pd.read_parquet("../data/playlist_track_features.parquet")

# %%
# %%time
mean_frame = combined_frame.groupby("playlist_id").mean().reset_index()
# Out:
# CPU times: user 2.4 s, sys: 844 ms, total: 3.24 s
# Wall time: 3.24 s

# %% [markdown]
# ## Percentiles

# %%
# %%time
perc_frames = {}
percentiles = [0.025] + [round(x ,2) for x in np.arange(0.05, 1, 0.05).tolist()] + [0.975]
for p in tqdm(percentiles):
    perc_frames[p] = combined_frame.groupby("playlist_id").quantile(p).reset_index()
# Out:
# 100%|██████████| 21/21 [26:09<00:00, 74.75s/it]
# CPU times: user 25min 30s, sys: 37.5 s, total: 26min 7s
# Wall time: 26min 9s

# %%
perc_frames_renamed = {}
for p, perc_frame in tqdm(perc_frames.items()):
    quantile_key = str(round(p*100,1)).replace('.','p')
    suffix = f'_percentile_{quantile_key}'
    perc_frames_renamed[quantile_key] = add_suffixes(perc_frame, suffix)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 41.39it/s]

# %%
for p, perc_frame in tqdm(perc_frames_renamed.items()):
    perc_frame.to_parquet(f"../data/track_features_distribution_statistics/track_features_percentile_{p}.parquet")
# Out:
# 100%|██████████| 21/21 [00:02<00:00,  8.35it/s]

# %% [markdown]
# ## Percentile Differences

# %%
iqr_frame = perc_frames[0.75].set_index("playlist_id").subtract(perc_frames[0.25].set_index("playlist_id")).reset_index()
iqr_frame_renamed = add_suffixes(iqr_frame, "_iqr")

# %%
iqr_max_frame = perc_frames[0.95].set_index("playlist_id").subtract(perc_frames[0.05].set_index("playlist_id")).reset_index()
iqr_max_frame_renamed = add_suffixes(iqr_max_frame, "_iqr_max")

# %%
iqr_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_iqr.parquet")
iqr_max_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_iqr_max.parquet")

# %% [markdown]
# ## Other distribution statistics

# %% [markdown]
# ### mean, var, std, std_error

# %%
mean_frame = combined_frame.groupby("playlist_id").mean().reset_index()

# %%
var_frame = combined_frame.groupby("playlist_id").var().reset_index()

# %%
std_frame = combined_frame.groupby("playlist_id").std().reset_index()

# %%
std_error_frame = combined_frame.groupby("playlist_id").sem().reset_index()

# %%
mean_frame_renamed = add_suffixes(mean_frame, "_mean")   
var_frame_renamed = add_suffixes(var_frame, "_var")   
std_frame_renamed = add_suffixes(std_frame, "_std")
std_error_frame_renamed = add_suffixes(std_error_frame, "_std_error")

# %%
mean_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_mean.parquet")
var_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_var.parquet")
std_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_std.parquet")
std_error_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_std_error.parquet")

# %% [markdown]
# ## skew, kurtosis

# %% [markdown]
# ### Unbiased

# %%
skew_unbiased_frame = combined_frame.groupby("playlist_id").skew().reset_index()

# %%
kurt_unbiased_frame = combined_frame.groupby("playlist_id").apply(pd.DataFrame.kurt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-371eb1302558> in <module>
#       1 kurt_unbiased_frame = combined_frame.groupby("playlist_id").apply(pd.DataFrame.kurt)
# ----> 2 kurt_unbiased_frame_renamed = add_suffixes(kurt_unbiased_frame, "_kurt_unbiased")
#
# <ipython-input-18-4f6d55d2aef4> in add_suffixes(frame, suffix)
#       1 def add_suffixes(frame, suffix):
#       2     renamed_frame = deepcopy(frame)
# ----> 3     renamed_frame.columns = [str(col) + suffix for col in renamed_frame.columns]
#       4     return renamed_frame
#
# ~/Documents/playlist-success/venv-playlist-success/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
skew_unbiased_frame_pivot = skew_unbiased_frame.reset_index().pivot(index='playlist_id', columns='level_1', values=0).reset_index().drop(columns=["track_id", "user_id"])
skew_unbiased_frame_renamed = add_suffixes(skew_unbiased_frame_pivot, "_skew_unbiased")

# %%
kurt_unbiased_frame_pivot = kurt_unbiased_frame.reset_index().pivot(index='playlist_id', columns='level_1', values=0).reset_index().drop(columns=["track_id", "user_id"])
kurt_unbiased_frame_renamed = add_suffixes(kurt_unbiased_frame_pivot, "_kurt_unbiased")

# %%
skew_ubbiased_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_skew_unbiased.parquet")
kurt_unbiased_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_kurt_unbiased.parquet")

# %% [markdown]
# ### Biased

# %%
skew_biased_frame = combined_frame.drop(columns=["track_id","user_id"]).groupby("playlist_id").apply(stats.skew)

# %%
kurt_biased_frame = combined_frame.drop(columns=["track_id","user_id"]).groupby("playlist_id").apply(stats.kurtosis)

# %%
feature_columns = ["popularity", "acousticness", "danceability", "duration", "energy", "instrumentalness", "key" ,
                   "liveness", "loudness", "mode", "speechiness", "tempo", "time", "valence"]

explode_feature_col = feature_columns * int(len(kurt_biased_frame.reset_index().explode(0)) / 14)

# %%
skew_biased_frame_pivot = skew_biased_frame.reset_index().explode(0).assign(features=explode_feature_col).pivot(index='playlist_id', columns='features', values=0).reset_index()
kurt_biased_frame_pivot = kurt_biased_frame.reset_index().explode(0).assign(features=explode_feature_col).pivot(index='playlist_id', columns='features', values=0).reset_index()

# %%
skew_biased_frame_renamed = add_suffixes(skew_biased_frame_pivot, "_skew_biased")
kurt_biased_frame_renamed = add_suffixes(kurt_biased_frame_pivot, "_kurt_biased")

# %%
skew_biased_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_skew_biased.parquet")
kurt_biased_frame_renamed.to_parquet("../data/track_features_distribution_statistics/track_features_kurt_biased.parquet")

# %% [markdown]
# ## Combining All Features

# %%
all_feature_frames = list(perc_frames_renamed.values()) + [
    mean_frame_renamed, 
    var_frame_ranamed, 
    std_frame_renamed,
    std_error_frame_renamed, 
    iqr_frame_renamed,
    iqr_max_frame_renamed,
    skew_unbiased_frame_renamed,
    kurt_unbiased_frame_renamed,
    kurt_biased_frame_renamed, 
    skew_biased_frame_renamed
]

# %%
# %%time
all_features = reduce(lambda left,right: pd.merge(left,right,on=['playlist_id'], how='outer'), all_feature_frames)
# Out:
# CPU times: user 2.53 s, sys: 1.55 s, total: 4.08 s
# Wall time: 4.09 s

# %%
# Final dataframe of all features
all_features.to_parquet("../data/track_features_all.parquet")

# %%
# analyze_cols = ["n_tracks", "n_artists", "n_albums", "tracks_per_album", "artists_per_album",'popularity', 'acousticness', 'danceability', 'duration', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time', 'valence']

# for col in analyze_cols:
#     fig, ax = plt.subplots(figsize=(20, 5))
#     sns.boxplot(x="success_streaming_ratio_users", y=col, data=snapshot, showfliers=False)
#     plt.title(col, size=30)
#     plt.xticks(rotation=90)
#     plt.show()

# %%
# analyze_cols = ["n_tracks", "n_artists", "n_albums", "tracks_per_album", "artists_per_album",'popularity', 'acousticness', 'danceability', 'duration', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time', 'valence']

# for col in analyze_cols:
#     fig, ax = plt.subplots(figsize=(20, 5))
#     sns.boxplot(x="genre_1", y=col, data=snapshot, order=snapshot["genre_1"].value_counts().index, hue="success_streaming_ratio_users", showfliers=False)
#     plt.title(col, size=30)
#     plt.xticks(rotation=90)
#     plt.show()

# %%
rvs5 = stats.norm.rvs(loc=8, scale=20, size=100)

# %%
type(rvs5)
# Out:
# numpy.ndarray

# %%
for col in all_features.columns:
    print(col)
# Out:
# playlist_id
# popularity_percentile_2p5
# acousticness_percentile_2p5
# danceability_percentile_2p5
# duration_percentile_2p5
# energy_percentile_2p5
# instrumentalness_percentile_2p5
# key_percentile_2p5
# liveness_percentile_2p5
# loudness_percentile_2p5
# mode_percentile_2p5
# speechiness_percentile_2p5
# tempo_percentile_2p5
# time_percentile_2p5
# valence_percentile_2p5
# popularity_percentile_5p0
# acousticness_percentile_5p0
# danceability_percentile_5p0
# duration_percentile_5p0
# energy_percentile_5p0
# instrumentalness_percentile_5p0
# key_percentile_5p0
# liveness_percentile_5p0
# loudness_percentile_5p0
# mode_percentile_5p0
# speechiness_percentile_5p0
# tempo_percentile_5p0
# time_percentile_5p0
# valence_percentile_5p0
# popularity_percentile_10p0
# acousticness_percentile_10p0
# danceability_percentile_10p0
# duration_percentile_10p0
# energy_percentile_10p0
# instrumentalness_percentile_10p0
# key_percentile_10p0
# liveness_percentile_10p0
# loudness_percentile_10p0
# mode_percentile_10p0
# speechiness_percentile_10p0
# tempo_percentile_10p0
# time_percentile_10p0
# valence_percentile_10p0
# popularity_percentile_15p0
# acousticness_percentile_15p0
# danceability_percentile_15p0
# duration_percentile_15p0
# energy_percentile_15p0
# instrumentalness_percentile_15p0
# key_percentile_15p0
# liveness_percentile_15p0
# loudness_percentile_15p0
# mode_percentile_15p0
# speechiness_percentile_15p0
# tempo_percentile_15p0
# time_percentile_15p0
# valence_percentile_15p0
# popularity_percentile_20p0
# acousticness_percentile_20p0
# danceability_percentile_20p0
# duration_percentile_20p0
# energy_percentile_20p0
# instrumentalness_percentile_20p0
# key_percentile_20p0
# liveness_percentile_20p0
# loudness_percentile_20p0
# mode_percentile_20p0
# speechiness_percentile_20p0
# tempo_percentile_20p0
# time_percentile_20p0
# valence_percentile_20p0
# popularity_percentile_25p0
# acousticness_percentile_25p0
# danceability_percentile_25p0
# duration_percentile_25p0
# energy_percentile_25p0
# instrumentalness_percentile_25p0
# key_percentile_25p0
# liveness_percentile_25p0
# loudness_percentile_25p0
# mode_percentile_25p0
# speechiness_percentile_25p0
# tempo_percentile_25p0
# time_percentile_25p0
# valence_percentile_25p0
# popularity_percentile_30p0
# acousticness_percentile_30p0
# danceability_percentile_30p0
# duration_percentile_30p0
# energy_percentile_30p0
# instrumentalness_percentile_30p0
# key_percentile_30p0
# liveness_percentile_30p0
# loudness_percentile_30p0
# mode_percentile_30p0
# speechiness_percentile_30p0
# tempo_percentile_30p0
# time_percentile_30p0
# valence_percentile_30p0
# popularity_percentile_35p0
# acousticness_percentile_35p0
# danceability_percentile_35p0
# duration_percentile_35p0
# energy_percentile_35p0
# instrumentalness_percentile_35p0
# key_percentile_35p0
# liveness_percentile_35p0
# loudness_percentile_35p0
# mode_percentile_35p0
# speechiness_percentile_35p0
# tempo_percentile_35p0
# time_percentile_35p0
# valence_percentile_35p0
# popularity_percentile_40p0
# acousticness_percentile_40p0
# danceability_percentile_40p0
# duration_percentile_40p0
# energy_percentile_40p0
# instrumentalness_percentile_40p0
# key_percentile_40p0
# liveness_percentile_40p0
# loudness_percentile_40p0
# mode_percentile_40p0
# speechiness_percentile_40p0
# tempo_percentile_40p0
# time_percentile_40p0
# valence_percentile_40p0
# popularity_percentile_45p0
# acousticness_percentile_45p0
# danceability_percentile_45p0
# duration_percentile_45p0
# energy_percentile_45p0
# instrumentalness_percentile_45p0
# key_percentile_45p0
# liveness_percentile_45p0
# loudness_percentile_45p0
# mode_percentile_45p0
# speechiness_percentile_45p0
# tempo_percentile_45p0
# time_percentile_45p0
# valence_percentile_45p0
# popularity_percentile_50p0
# acousticness_percentile_50p0
# danceability_percentile_50p0
# duration_percentile_50p0
# energy_percentile_50p0
# instrumentalness_percentile_50p0
# key_percentile_50p0
# liveness_percentile_50p0
# loudness_percentile_50p0
# mode_percentile_50p0
# speechiness_percentile_50p0
# tempo_percentile_50p0
# time_percentile_50p0
# valence_percentile_50p0
# popularity_percentile_55p0
# acousticness_percentile_55p0
# danceability_percentile_55p0
# duration_percentile_55p0
# energy_percentile_55p0
# instrumentalness_percentile_55p0
# key_percentile_55p0
# liveness_percentile_55p0
# loudness_percentile_55p0
# mode_percentile_55p0
# speechiness_percentile_55p0
# tempo_percentile_55p0
# time_percentile_55p0
# valence_percentile_55p0
# popularity_percentile_60p0
# acousticness_percentile_60p0
# danceability_percentile_60p0
# duration_percentile_60p0
# energy_percentile_60p0
# instrumentalness_percentile_60p0
# key_percentile_60p0
# liveness_percentile_60p0
# loudness_percentile_60p0
# mode_percentile_60p0
# speechiness_percentile_60p0
# tempo_percentile_60p0
# time_percentile_60p0
# valence_percentile_60p0
# popularity_percentile_65p0
# acousticness_percentile_65p0
# danceability_percentile_65p0
# duration_percentile_65p0
# energy_percentile_65p0
# instrumentalness_percentile_65p0
# key_percentile_65p0
# liveness_percentile_65p0
# loudness_percentile_65p0
# mode_percentile_65p0
# speechiness_percentile_65p0
# tempo_percentile_65p0
# time_percentile_65p0
# valence_percentile_65p0
# popularity_percentile_70p0
# acousticness_percentile_70p0
# danceability_percentile_70p0
# duration_percentile_70p0
# energy_percentile_70p0
# instrumentalness_percentile_70p0
# key_percentile_70p0
# liveness_percentile_70p0
# loudness_percentile_70p0
# mode_percentile_70p0
# speechiness_percentile_70p0
# tempo_percentile_70p0
# time_percentile_70p0
# valence_percentile_70p0
# popularity_percentile_75p0
# acousticness_percentile_75p0
# danceability_percentile_75p0
# duration_percentile_75p0
# energy_percentile_75p0
# instrumentalness_percentile_75p0
# key_percentile_75p0
# liveness_percentile_75p0
# loudness_percentile_75p0
# mode_percentile_75p0
# speechiness_percentile_75p0
# tempo_percentile_75p0
# time_percentile_75p0
# valence_percentile_75p0
# popularity_percentile_80p0
# acousticness_percentile_80p0
# danceability_percentile_80p0
# duration_percentile_80p0
# energy_percentile_80p0
# instrumentalness_percentile_80p0
# key_percentile_80p0
# liveness_percentile_80p0
# loudness_percentile_80p0
# mode_percentile_80p0
# speechiness_percentile_80p0
# tempo_percentile_80p0
# time_percentile_80p0
# valence_percentile_80p0
# popularity_percentile_85p0
# acousticness_percentile_85p0
# danceability_percentile_85p0
# duration_percentile_85p0
# energy_percentile_85p0
# instrumentalness_percentile_85p0
# key_percentile_85p0
# liveness_percentile_85p0
# loudness_percentile_85p0
# mode_percentile_85p0
# speechiness_percentile_85p0
# tempo_percentile_85p0
# time_percentile_85p0
# valence_percentile_85p0
# popularity_percentile_90p0
# acousticness_percentile_90p0
# danceability_percentile_90p0
# duration_percentile_90p0
# energy_percentile_90p0
# instrumentalness_percentile_90p0
# key_percentile_90p0
# liveness_percentile_90p0
# loudness_percentile_90p0
# mode_percentile_90p0
# speechiness_percentile_90p0
# tempo_percentile_90p0
# time_percentile_90p0
# valence_percentile_90p0
# popularity_percentile_95p0
# acousticness_percentile_95p0
# danceability_percentile_95p0
# duration_percentile_95p0
# energy_percentile_95p0
# instrumentalness_percentile_95p0
# key_percentile_95p0
# liveness_percentile_95p0
# loudness_percentile_95p0
# mode_percentile_95p0
# speechiness_percentile_95p0
# tempo_percentile_95p0
# time_percentile_95p0
# valence_percentile_95p0
# popularity_percentile_97p5
# acousticness_percentile_97p5
# danceability_percentile_97p5
# duration_percentile_97p5
# energy_percentile_97p5
# instrumentalness_percentile_97p5
# key_percentile_97p5
# liveness_percentile_97p5
# loudness_percentile_97p5
# mode_percentile_97p5
# speechiness_percentile_97p5
# tempo_percentile_97p5
# time_percentile_97p5
# valence_percentile_97p5
# popularity_mean
# acousticness_mean
# danceability_mean
# duration_mean
# energy_mean
# instrumentalness_mean
# key_mean
# liveness_mean
# loudness_mean
# mode_mean
# speechiness_mean
# tempo_mean
# time_mean
# valence_mean
# popularity_var
# acousticness_var
# danceability_var
# duration_var
# energy_var
# instrumentalness_var
# key_var
# liveness_var
# loudness_var
# mode_var
# speechiness_var
# tempo_var
# time_var
# valence_var
# popularity_std
# acousticness_std
# danceability_std
# duration_std
# energy_std
# instrumentalness_std
# key_std
# liveness_std
# loudness_std
# mode_std
# speechiness_std
# tempo_std
# time_std
# valence_std
# popularity_std_error
# acousticness_std_error
# danceability_std_error
# duration_std_error
# energy_std_error
# instrumentalness_std_error
# key_std_error
# liveness_std_error
# loudness_std_error
# mode_std_error
# speechiness_std_error
# tempo_std_error
# time_std_error
# valence_std_error
# popularity_iqr
# acousticness_iqr
# danceability_iqr
# duration_iqr
# energy_iqr
# instrumentalness_iqr
# key_iqr
# liveness_iqr
# loudness_iqr
# mode_iqr
# speechiness_iqr
# tempo_iqr
# time_iqr
# valence_iqr
# popularity_iqr_max
# acousticness_iqr_max
# danceability_iqr_max
# duration_iqr_max
# energy_iqr_max
# instrumentalness_iqr_max
# key_iqr_max
# liveness_iqr_max
# loudness_iqr_max
# mode_iqr_max
# speechiness_iqr_max
# tempo_iqr_max
# time_iqr_max
# valence_iqr_max
# acousticness_skew_unbiased
# danceability_skew_unbiased
# duration_skew_unbiased
# energy_skew_unbiased
# instrumentalness_skew_unbiased
# key_skew_unbiased
# liveness_skew_unbiased
# loudness_skew_unbiased
# mode_skew_unbiased
# popularity_skew_unbiased
# speechiness_skew_unbiased
# tempo_skew_unbiased
# time_skew_unbiased
# valence_skew_unbiased
# acousticness_kurt_unbiased
# danceability_kurt_unbiased
# duration_kurt_unbiased
# energy_kurt_unbiased
# instrumentalness_kurt_unbiased
# key_kurt_unbiased
# liveness_kurt_unbiased
# loudness_kurt_unbiased
# mode_kurt_unbiased
# popularity_kurt_unbiased
# speechiness_kurt_unbiased
# tempo_kurt_unbiased
# time_kurt_unbiased
# valence_kurt_unbiased
# acousticness_kurt_biased
# danceability_kurt_biased
# duration_kurt_biased
# energy_kurt_biased
# instrumentalness_kurt_biased
# key_kurt_biased
# liveness_kurt_biased
# loudness_kurt_biased
# mode_kurt_biased
# popularity_kurt_biased
# speechiness_kurt_biased
# tempo_kurt_biased
# time_kurt_biased
# valence_kurt_biased
# acousticness_skew_biased
# danceability_skew_biased
# duration_skew_biased
# energy_skew_biased
# instrumentalness_skew_biased
# key_skew_biased
# liveness_skew_biased
# loudness_skew_biased
# mode_skew_biased
# popularity_skew_biased
# speechiness_skew_biased
# tempo_skew_biased
# time_skew_biased
# valence_skew_biased
